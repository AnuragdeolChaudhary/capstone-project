# %% [markdown]
# # Explore and cluster the neighborhoods in Toronto

# %%
# install geopy & folium
# !conda install -c conda-forge geopy --yes
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Anuj\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.3.9           |           py37_0         149 KB  conda-forge
#     conda-4.8.3                |   py37hc8dfbb8_1         3.1 MB  conda-forge
#     conda-package-handling-1.6.0|   py37h702c6c1_2         691 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   conda-package-han~ conda-forge/win-64::conda-package-handling-1.6.0-py37h702c6c1_2
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#   python_abi         conda-forge/win-64::python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   conda                      pkgs/main::conda-4.6.11-py37_0 --> conda-forge::conda-4.8.3-py37hc8dfbb8_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> conda-forge
#
#
#
# Downloading and Extracting Packages
#
# certifi-2019.3.9     | 149 KB    |            |   0%
# certifi-2019.3.9     | 149 KB    | 8          |   8%
# certifi-2019.3.9     | 149 KB    | #######5   |  75%
# certifi-2019.3.9     | 149 KB    | ########## | 100%
#
# conda-package-handli | 691 KB    |            |   0%
# conda-package-handli | 691 KB    | 1          |   2%
# conda-package-handli | 691 KB    | ##         |  21%
# conda-package-handli | 691 KB    | ####1      |  42%
# conda-package-handli | 691 KB    | #####9     |  59%
# conda-package-handli | 691 KB    | #######1   |  71%
# conda-package-handli | 691 KB    | ########1  |  82%
# conda-package-handli | 691 KB    | #########3 |  93%
# conda-package-handli | 691 KB    | ########## | 100%
#
# geographiclib-1.50   | 34 KB     |            |   0%
# geographiclib-1.50   | 34 KB     | ###5       |  35%
# geographiclib-1.50   | 34 KB     | ########## | 100%
#
# python_abi-3.7       | 4 KB      |            |   0%
# python_abi-3.7       | 4 KB      | #######5   |  75%
# python_abi-3.7       | 4 KB      | ########## | 100%
#
# conda-4.8.3          | 3.1 MB    |            |   0%
# conda-4.8.3          | 3.1 MB    |            |   0%
# conda-4.8.3          | 3.1 MB    | 3          |   3%
# conda-4.8.3          | 3.1 MB    | 4          |   5%
# conda-4.8.3          | 3.1 MB    | 7          |   7%
# conda-4.8.3          | 3.1 MB    | 9          |  10%
# conda-4.8.3          | 3.1 MB    | #2         |  12%
# conda-4.8.3          | 3.1 MB    | #4         |  15%
# conda-4.8.3          | 3.1 MB    | #6         |  17%
# conda-4.8.3          | 3.1 MB    | #8         |  19%
# conda-4.8.3          | 3.1 MB    | ##1        |  22%
# conda-4.8.3          | 3.1 MB    | ##5        |  26%
# conda-4.8.3          | 3.1 MB    | ##8        |  28%
# conda-4.8.3          | 3.1 MB    | ###1       |  31%
# conda-4.8.3          | 3.1 MB    | ###4       |  34%
# conda-4.8.3          | 3.1 MB    | ###6       |  37%
# conda-4.8.3          | 3.1 MB    | ###9       |  39%
# conda-4.8.3          | 3.1 MB    | ####1      |  42%
# conda-4.8.3          | 3.1 MB    | ####3      |  44%
# conda-4.8.3          | 3.1 MB    | ####8      |  49%
# conda-4.8.3          | 3.1 MB    | #####3     |  53%
# conda-4.8.3          | 3.1 MB    | #####7     |  58%
# conda-4.8.3          | 3.1 MB    | ######1    |  61%
# conda-4.8.3          | 3.1 MB    | ######4    |  64%
# conda-4.8.3          | 3.1 MB    | ######7    |  68%
# conda-4.8.3          | 3.1 MB    | #######    |  71%
# conda-4.8.3          | 3.1 MB    | #######3   |  74%
# conda-4.8.3          | 3.1 MB    | #######6   |  76%
# conda-4.8.3          | 3.1 MB    | #######8   |  79%
# conda-4.8.3          | 3.1 MB    | ########   |  81%
# conda-4.8.3          | 3.1 MB    | ########3  |  84%
# conda-4.8.3          | 3.1 MB    | ########7  |  88%
# conda-4.8.3          | 3.1 MB    | #########  |  90%
# conda-4.8.3          | 3.1 MB    | #########2 |  92%
# conda-4.8.3          | 3.1 MB    | #########4 |  94%
# conda-4.8.3          | 3.1 MB    | #########5 |  96%
# conda-4.8.3          | 3.1 MB    | #########9 |  99%
# conda-4.8.3          | 3.1 MB    | ########## | 100%
#
# geopy-2.0.0          | 63 KB     |            |   0%
# geopy-2.0.0          | 63 KB     | #8         |  19%
# geopy-2.0.0          | 63 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# (base) C:\Users\Anuj>ET _sysp=%~dpA
#
# (base) C:\Users\Anuj>IF NOT EXIST "!_sysp!\Scripts\conda.exe"
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2019.03=py37_0
#   - defaults/win-64::numba==0.43.1=py37hf9181ef_0
# done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Anuj\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.02  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           2 KB
#     argh-0.26.2                |        py37_1001          33 KB  conda-forge
#     autopep8-1.5.2             |     pyh9f0ad1d_0          39 KB  conda-forge
#     bcrypt-3.1.7               |   py37h8055547_1          40 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         184 KB  conda-forge
#     certifi-2020.6.20          |   py37hc8dfbb8_0         151 KB  conda-forge
#     diff-match-patch-20181111  |             py_0          37 KB  conda-forge
#     flake8-3.7.9               |   py37hc8dfbb8_1         147 KB  conda-forge
#     fsspec-0.7.4               |             py_0          55 KB  conda-forge
#     hypothesis-4.39.0          |           py37_0         357 KB  conda-forge
#     intervaltree-3.0.2         |             py_0          23 KB  conda-forge
#     joblib-0.15.1              |             py_0         202 KB  conda-forge
#     json5-0.9.4                |     pyh9f0ad1d_0          20 KB  conda-forge
#     libspatialindex-1.9.3      |       he025d50_3         380 KB  conda-forge
#     matplotlib-base-3.1.1      |   py37h2852a4a_1         6.6 MB  conda-forge
#     mock-4.0.2                 |   py37hc8dfbb8_0          50 KB  conda-forge
#     openssl-1.1.1f             |       hfa6e2cd_0         4.7 MB  conda-forge
#     paramiko-2.7.1             |           py37_0         281 KB  conda-forge
#     path-14.0.1                |   py37hc8dfbb8_0          38 KB  conda-forge
#     pathtools-0.1.2            |             py_1           8 KB  conda-forge
#     pexpect-4.8.0              |   py37hc8dfbb8_1          79 KB  conda-forge
#     pydocstyle-5.0.2           |             py_0          32 KB  conda-forge
#     pynacl-1.3.0               |py37h2fa13f4_1001         1.4 MB  conda-forge
#     pytest-astropy-header-0.1.2|             py_0          10 KB  conda-forge
#     python-jsonrpc-server-0.3.4|             py_0          11 KB  conda-forge
#     python-language-server-0.28.1|           py37_0          75 KB  conda-forge
#     pywin32-ctypes-0.2.0       |py37hc8dfbb8_1001          38 KB  conda-forge
#     qdarkstyle-2.8.1           |     pyh9f0ad1d_0         154 KB  conda-forge
#     rtree-0.9.4                |   py37h804a536_1          43 KB  conda-forge
#     sphinxcontrib-applehelp-1.0.2|             py_0          28 KB  conda-forge
#     sphinxcontrib-devhelp-1.0.2|             py_0          22 KB  conda-forge
#     sphinxcontrib-htmlhelp-1.0.3|             py_0          27 KB  conda-forge
#     sphinxcontrib-jsmath-1.0.1 |             py_0           7 KB  conda-forge
#     sphinxcontrib-qthelp-1.0.3 |             py_0          25 KB  conda-forge
#     sphinxcontrib-serializinghtml-1.1.4|             py_0          24 KB  conda-forge
#     tbb-2020.1                 |       he980bc4_0         167 KB  conda-forge
#     ujson-2.0.3                |   py37h63f7a3c_0          48 KB  conda-forge
#     watchdog-0.10.3            |   py37hc8dfbb8_0         109 KB  conda-forge
#     yapf-0.29.0                |             py_0         119 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        15.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2020.02-py37_0
#   argh               conda-forge/win-64::argh-0.26.2-py37_1001
#   autopep8           conda-forge/noarch::autopep8-1.5.2-pyh9f0ad1d_0
#   bcrypt             conda-forge/win-64::bcrypt-3.1.7-py37h8055547_1
#   diff-match-patch   conda-forge/noarch::diff-match-patch-20181111-py_0
#   flake8             conda-forge/win-64::flake8-3.7.9-py37hc8dfbb8_1
#   fsspec             conda-forge/noarch::fsspec-0.7.4-py_0
#   hypothesis         conda-forge/win-64::hypothesis-4.39.0-py37_0
#   intervaltree       conda-forge/noarch::intervaltree-3.0.2-py_0
#   joblib             conda-forge/noarch::joblib-0.15.1-py_0
#   json5              conda-forge/noarch::json5-0.9.4-pyh9f0ad1d_0
#   libspatialindex    conda-forge/win-64::libspatialindex-1.9.3-he025d50_3
#   matplotlib-base    conda-forge/win-64::matplotlib-base-3.1.1-py37h2852a4a_1
#   mock               conda-forge/win-64::mock-4.0.2-py37hc8dfbb8_0
#   paramiko           conda-forge/win-64::paramiko-2.7.1-py37_0
#   path               conda-forge/win-64::path-14.0.1-py37hc8dfbb8_0
#   pathtools          conda-forge/noarch::pathtools-0.1.2-py_1
#   pexpect            conda-forge/win-64::pexpect-4.8.0-py37hc8dfbb8_1
#   pydocstyle         conda-forge/noarch::pydocstyle-5.0.2-py_0
#   pynacl             conda-forge/win-64::pynacl-1.3.0-py37h2fa13f4_1001
#   pytest-astropy-he~ conda-forge/noarch::pytest-astropy-header-0.1.2-py_0
#   python-jsonrpc-se~ conda-forge/noarch::python-jsonrpc-server-0.3.4-py_0
#   python-language-s~ conda-forge/win-64::python-language-server-0.28.1-py37_0
#   pywin32-ctypes     conda-forge/win-64::pywin32-ctypes-0.2.0-py37hc8dfbb8_1001
#   qdarkstyle         conda-forge/noarch::qdarkstyle-2.8.1-pyh9f0ad1d_0
#   rtree              conda-forge/win-64::rtree-0.9.4-py37h804a536_1
#   sphinxcontrib-app~ conda-forge/noarch::sphinxcontrib-applehelp-1.0.2-py_0
#   sphinxcontrib-dev~ conda-forge/noarch::sphinxcontrib-devhelp-1.0.2-py_0
#   sphinxcontrib-htm~ conda-forge/noarch::sphinxcontrib-htmlhelp-1.0.3-py_0
#   sphinxcontrib-jsm~ conda-forge/noarch::sphinxcontrib-jsmath-1.0.1-py_0
#   sphinxcontrib-qth~ conda-forge/noarch::sphinxcontrib-qthelp-1.0.3-py_0
#   sphinxcontrib-ser~ conda-forge/noarch::sphinxcontrib-serializinghtml-1.1.4-py_0
#   tbb                conda-forge/win-64::tbb-2020.1-he980bc4_0
#   ujson              conda-forge/win-64::ujson-2.0.3-py37h63f7a3c_0
#   watchdog           conda-forge/win-64::watchdog-0.10.3-py37hc8dfbb8_0
#   yapf               conda-forge/noarch::yapf-0.29.0-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.1.23-0 --> conda-forge::ca-certificates-2020.6.20-hecda079_0
#   certifi                                   2019.3.9-py37_0 --> 2020.6.20-py37hc8dfbb8_0
#   openssl              pkgs/main::openssl-1.1.1b-he774522_1 --> conda-forge::openssl-1.1.1f-hfa6e2cd_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2019.03-py37_0 --> custom-py37_1
#
#
#
# Downloading and Extracting Packages
#
# intervaltree-3.0.2   | 23 KB     |            |   0%
# intervaltree-3.0.2   | 23 KB     | ######9    |  69%
# intervaltree-3.0.2   | 23 KB     | ########## | 100%
#
# python-jsonrpc-serve | 11 KB     |            |   0%
# python-jsonrpc-serve | 11 KB     | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# joblib-0.15.1        | 202 KB    |            |   0%
# joblib-0.15.1        | 202 KB    | 7          |   8%
# joblib-0.15.1        | 202 KB    | ###9       |  40%
# joblib-0.15.1        | 202 KB    | #####5     |  55%
# joblib-0.15.1        | 202 KB    | ########7  |  87%
# joblib-0.15.1        | 202 KB    | ########## | 100%
#
# matplotlib-base-3.1. | 6.6 MB    |            |   0%
# matplotlib-base-3.1. | 6.6 MB    |            |   0%
# matplotlib-base-3.1. | 6.6 MB    | 1          |   1%
# matplotlib-base-3.1. | 6.6 MB    | 2          |   2%
# matplotlib-base-3.1. | 6.6 MB    | 4          |   5%
# matplotlib-base-3.1. | 6.6 MB    | 6          |   6%
# matplotlib-base-3.1. | 6.6 MB    | 7          |   8%
# matplotlib-base-3.1. | 6.6 MB    | 9          |   9%
# matplotlib-base-3.1. | 6.6 MB    | #1         |  11%
# matplotlib-base-3.1. | 6.6 MB    | #3         |  13%
# matplotlib-base-3.1. | 6.6 MB    | #4         |  15%
# matplotlib-base-3.1. | 6.6 MB    | #6         |  16%
# matplotlib-base-3.1. | 6.6 MB    | #7         |  17%
# matplotlib-base-3.1. | 6.6 MB    | #9         |  19%
# matplotlib-base-3.1. | 6.6 MB    | ##         |  21%
# matplotlib-base-3.1. | 6.6 MB    | ##2        |  22%
# matplotlib-base-3.1. | 6.6 MB    | ##3        |  24%
# matplotlib-base-3.1. | 6.6 MB    | ##4        |  25%
# matplotlib-base-3.1. | 6.6 MB    | ##6        |  26%
# matplotlib-base-3.1. | 6.6 MB    | ##7        |  27%
# matplotlib-base-3.1. | 6.6 MB    | ##8        |  28%
# matplotlib-base-3.1. | 6.6 MB    | ###        |  31%
# matplotlib-base-3.1. | 6.6 MB    | ###2       |  33%
# matplotlib-base-3.1. | 6.6 MB    | ###5       |  35%
# matplotlib-base-3.1. | 6.6 MB    | ###6       |  37%
# matplotlib-base-3.1. | 6.6 MB    | ###8       |  38%
# matplotlib-base-3.1. | 6.6 MB    | ###9       |  40%
# matplotlib-base-3.1. | 6.6 MB    | ####1      |  41%
# matplotlib-base-3.1. | 6.6 MB    | ####2      |  42%
# matplotlib-base-3.1. | 6.6 MB    | ####4      |  44%
# matplotlib-base-3.1. | 6.6 MB    | ####7      |  47%
# matplotlib-base-3.1. | 6.6 MB    | ####8      |  49%
# matplotlib-base-3.1. | 6.6 MB    | #####1     |  51%
# matplotlib-base-3.1. | 6.6 MB    | #####3     |  53%
# matplotlib-base-3.1. | 6.6 MB    | #####5     |  55%
# matplotlib-base-3.1. | 6.6 MB    | #####6     |  57%
# matplotlib-base-3.1. | 6.6 MB    | #####8     |  58%
# matplotlib-base-3.1. | 6.6 MB    | ######1    |  61%
# matplotlib-base-3.1. | 6.6 MB    | ######3    |  63%
# matplotlib-base-3.1. | 6.6 MB    | ######5    |  65%
# matplotlib-base-3.1. | 6.6 MB    | ######6    |  67%
# matplotlib-base-3.1. | 6.6 MB    | ######9    |  70%
# matplotlib-base-3.1. | 6.6 MB    | #######2   |  73%
# matplotlib-base-3.1. | 6.6 MB    | #######5   |  75%
# matplotlib-base-3.1. | 6.6 MB    | #######7   |  78%
# matplotlib-base-3.1. | 6.6 MB    | #######9   |  80%
# matplotlib-base-3.1. | 6.6 MB    | ########1  |  82%
# matplotlib-base-3.1. | 6.6 MB    | ########4  |  85%
# matplotlib-base-3.1. | 6.6 MB    | ########7  |  87%
# matplotlib-base-3.1. | 6.6 MB    | ########9  |  89%
# matplotlib-base-3.1. | 6.6 MB    | #########  |  91%
# matplotlib-base-3.1. | 6.6 MB    | #########2 |  93%
# matplotlib-base-3.1. | 6.6 MB    | #########4 |  94%
# matplotlib-base-3.1. | 6.6 MB    | #########6 |  96%
# matplotlib-base-3.1. | 6.6 MB    | #########7 |  98%
# matplotlib-base-3.1. | 6.6 MB    | #########9 |  99%
# matplotlib-base-3.1. | 6.6 MB    | ########## | 100%
#
# pexpect-4.8.0        | 79 KB     |            |   0%
# pexpect-4.8.0        | 79 KB     | ##         |  20%
# pexpect-4.8.0        | 79 KB     | ########   |  81%
# pexpect-4.8.0        | 79 KB     | ########## | 100%
#
# json5-0.9.4          | 20 KB     |            |   0%
# json5-0.9.4          | 20 KB     | #######9   |  79%
# json5-0.9.4          | 20 KB     | ########## | 100%
#
# tbb-2020.1           | 167 KB    |            |   0%
# tbb-2020.1           | 167 KB    | 9          |  10%
# tbb-2020.1           | 167 KB    | ########6  |  86%
# tbb-2020.1           | 167 KB    | ########## | 100%
#
# openssl-1.1.1f       | 4.7 MB    |            |   0%
# openssl-1.1.1f       | 4.7 MB    |            |   0%
# openssl-1.1.1f       | 4.7 MB    | 1          |   2%
# openssl-1.1.1f       | 4.7 MB    | 2          |   3%
# openssl-1.1.1f       | 4.7 MB    | 4          |   5%
# openssl-1.1.1f       | 4.7 MB    | 6          |   7%
# openssl-1.1.1f       | 4.7 MB    | 8          |   9%
# openssl-1.1.1f       | 4.7 MB    | #          |  11%
# openssl-1.1.1f       | 4.7 MB    | #2         |  13%
# openssl-1.1.1f       | 4.7 MB    | #4         |  14%
# openssl-1.1.1f       | 4.7 MB    | #7         |  17%
# openssl-1.1.1f       | 4.7 MB    | #9         |  20%
# openssl-1.1.1f       | 4.7 MB    | ##1        |  22%
# openssl-1.1.1f       | 4.7 MB    | ##3        |  23%
# openssl-1.1.1f       | 4.7 MB    | ##5        |  25%
# openssl-1.1.1f       | 4.7 MB    | ##6        |  27%
# openssl-1.1.1f       | 4.7 MB    | ##8        |  29%
# openssl-1.1.1f       | 4.7 MB    | ###        |  30%
# openssl-1.1.1f       | 4.7 MB    | ###2       |  32%
# openssl-1.1.1f       | 4.7 MB    | ###6       |  36%
# openssl-1.1.1f       | 4.7 MB    | ###8       |  38%
# openssl-1.1.1f       | 4.7 MB    | ####       |  40%
# openssl-1.1.1f       | 4.7 MB    | ####1      |  42%
# openssl-1.1.1f       | 4.7 MB    | ####3      |  43%
# openssl-1.1.1f       | 4.7 MB    | ####5      |  46%
# openssl-1.1.1f       | 4.7 MB    | ####8      |  48%
# openssl-1.1.1f       | 4.7 MB    | #####      |  50%
# openssl-1.1.1f       | 4.7 MB    | #####2     |  52%
# openssl-1.1.1f       | 4.7 MB    | #####4     |  54%
# openssl-1.1.1f       | 4.7 MB    | #####6     |  56%
# openssl-1.1.1f       | 4.7 MB    | #####8     |  59%
# openssl-1.1.1f       | 4.7 MB    | ######     |  61%
# openssl-1.1.1f       | 4.7 MB    | ######2    |  63%
# openssl-1.1.1f       | 4.7 MB    | ######5    |  66%
# openssl-1.1.1f       | 4.7 MB    | ######7    |  68%
# openssl-1.1.1f       | 4.7 MB    | #######    |  71%
# openssl-1.1.1f       | 4.7 MB    | #######2   |  73%
# openssl-1.1.1f       | 4.7 MB    | #######4   |  75%
# openssl-1.1.1f       | 4.7 MB    | #######6   |  77%
# openssl-1.1.1f       | 4.7 MB    | #######8   |  78%
# openssl-1.1.1f       | 4.7 MB    | ########   |  81%
# openssl-1.1.1f       | 4.7 MB    | ########2  |  82%
# openssl-1.1.1f       | 4.7 MB    | ########4  |  84%
# openssl-1.1.1f       | 4.7 MB    | ########5  |  86%
# openssl-1.1.1f       | 4.7 MB    | ########7  |  88%
# openssl-1.1.1f       | 4.7 MB    | ########9  |  89%
# openssl-1.1.1f       | 4.7 MB    | #########  |  90%
# openssl-1.1.1f       | 4.7 MB    | #########1 |  92%
# openssl-1.1.1f       | 4.7 MB    | #########3 |  93%
# openssl-1.1.1f       | 4.7 MB    | #########4 |  94%
# openssl-1.1.1f       | 4.7 MB    | #########8 |  98%
# openssl-1.1.1f       | 4.7 MB    | ########## | 100%
#
# pathtools-0.1.2      | 8 KB      |            |   0%
# pathtools-0.1.2      | 8 KB      | ########## | 100%
#
# bcrypt-3.1.7         | 40 KB     |            |   0%
# bcrypt-3.1.7         | 40 KB     | ####       |  40%
# bcrypt-3.1.7         | 40 KB     | ########## | 100%
#
# libspatialindex-1.9. | 380 KB    |            |   0%
# libspatialindex-1.9. | 380 KB    | 4          |   4%
# libspatialindex-1.9. | 380 KB    | ##1        |  21%
# libspatialindex-1.9. | 380 KB    | ####2      |  42%
# libspatialindex-1.9. | 380 KB    | #######5   |  76%
# libspatialindex-1.9. | 380 KB    | #########6 |  97%
# libspatialindex-1.9. | 380 KB    | ########## | 100%
#
# pytest-astropy-heade | 10 KB     |            |   0%
# pytest-astropy-heade | 10 KB     | ########## | 100%
#
# ca-certificates-2020 | 184 KB    |            |   0%
# ca-certificates-2020 | 184 KB    | 8          |   9%
# ca-certificates-2020 | 184 KB    | ######1    |  61%
# ca-certificates-2020 | 184 KB    | ########7  |  87%
# ca-certificates-2020 | 184 KB    | ########## | 100%
#
# sphinxcontrib-htmlhe | 27 KB     |            |   0%
# sphinxcontrib-htmlhe | 27 KB     | #####8     |  59%
# sphinxcontrib-htmlhe | 27 KB     | ########## | 100%
#
# sphinxcontrib-jsmath | 7 KB      |            |   0%
# sphinxcontrib-jsmath | 7 KB      | ########## | 100%
#
# watchdog-0.10.3      | 109 KB    |            |   0%
# watchdog-0.10.3      | 109 KB    | #4         |  15%
# watchdog-0.10.3      | 109 KB    | #######3   |  73%
# watchdog-0.10.3      | 109 KB    | ########## | 100%
#
# pynacl-1.3.0         | 1.4 MB    |            |   0%
# pynacl-1.3.0         | 1.4 MB    | 1          |   1%
# pynacl-1.3.0         | 1.4 MB    | 4          |   4%
# pynacl-1.3.0         | 1.4 MB    | 8          |   9%
# pynacl-1.3.0         | 1.4 MB    | #4         |  14%
# pynacl-1.3.0         | 1.4 MB    | #7         |  18%
# pynacl-1.3.0         | 1.4 MB    | ##3        |  23%
# pynacl-1.3.0         | 1.4 MB    | ##7        |  27%
# pynacl-1.3.0         | 1.4 MB    | ###        |  31%
# pynacl-1.3.0         | 1.4 MB    | ###4       |  34%
# pynacl-1.3.0         | 1.4 MB    | ###8       |  38%
# pynacl-1.3.0         | 1.4 MB    | ####1      |  42%
# pynacl-1.3.0         | 1.4 MB    | ####5      |  45%
# pynacl-1.3.0         | 1.4 MB    | #####      |  51%
# pynacl-1.3.0         | 1.4 MB    | #####6     |  56%
# pynacl-1.3.0         | 1.4 MB    | ######2    |  63%
# pynacl-1.3.0         | 1.4 MB    | ######8    |  68%
# pynacl-1.3.0         | 1.4 MB    | #######8   |  78%
# pynacl-1.3.0         | 1.4 MB    | ########4  |  85%
# pynacl-1.3.0         | 1.4 MB    | #########1 |  91%
# pynacl-1.3.0         | 1.4 MB    | #########6 |  97%
# pynacl-1.3.0         | 1.4 MB    | ########## | 100%
#
# path-14.0.1          | 38 KB     |            |   0%
# path-14.0.1          | 38 KB     | ####2      |  42%
# path-14.0.1          | 38 KB     | ########## | 100%
#
# mock-4.0.2           | 50 KB     |            |   0%
# mock-4.0.2           | 50 KB     | ###1       |  32%
# mock-4.0.2           | 50 KB     | ########## | 100%
#
# yapf-0.29.0          | 119 KB    |            |   0%
# yapf-0.29.0          | 119 KB    | #3         |  13%
# yapf-0.29.0          | 119 KB    | ########## | 100%
#
# paramiko-2.7.1       | 281 KB    |            |   0%
# paramiko-2.7.1       | 281 KB    | 5          |   6%
# paramiko-2.7.1       | 281 KB    | #7         |  17%
# paramiko-2.7.1       | 281 KB    | #####1     |  51%
# paramiko-2.7.1       | 281 KB    | ########5  |  85%
# paramiko-2.7.1       | 281 KB    | ########## | 100%
#
# hypothesis-4.39.0    | 357 KB    |            |   0%
# hypothesis-4.39.0    | 357 KB    | 4          |   4%
# hypothesis-4.39.0    | 357 KB    | ##6        |  27%
# hypothesis-4.39.0    | 357 KB    | ########## | 100%
#
# rtree-0.9.4          | 43 KB     |            |   0%
# rtree-0.9.4          | 43 KB     | ###7       |  37%
# rtree-0.9.4          | 43 KB     | ########## | 100%
#
# sphinxcontrib-serial | 24 KB     |            |   0%
# sphinxcontrib-serial | 24 KB     | ######6    |  67%
# sphinxcontrib-serial | 24 KB     | ########## | 100%
#
# sphinxcontrib-qthelp | 25 KB     |            |   0%
# sphinxcontrib-qthelp | 25 KB     | ######3    |  64%
# sphinxcontrib-qthelp | 25 KB     | ########## | 100%
#
# qdarkstyle-2.8.1     | 154 KB    |            |   0%
# qdarkstyle-2.8.1     | 154 KB    | #          |  10%
# qdarkstyle-2.8.1     | 154 KB    | ########## | 100%
#
# sphinxcontrib-devhel | 22 KB     |            |   0%
# sphinxcontrib-devhel | 22 KB     | #######1   |  71%
# sphinxcontrib-devhel | 22 KB     | ########## | 100%
#
# pydocstyle-5.0.2     | 32 KB     |            |   0%
# pydocstyle-5.0.2     | 32 KB     | ####9      |  50%
# pydocstyle-5.0.2     | 32 KB     | ########## | 100%
#
# flake8-3.7.9         | 147 KB    |            |   0%
# flake8-3.7.9         | 147 KB    | #          |  11%
# flake8-3.7.9         | 147 KB    | ######5    |  65%
# flake8-3.7.9         | 147 KB    | ########## | 100%
#
# ujson-2.0.3          | 48 KB     |            |   0%
# ujson-2.0.3          | 48 KB     | ###3       |  33%
# ujson-2.0.3          | 48 KB     | ########## | 100%
#
# sphinxcontrib-appleh | 28 KB     |            |   0%
# sphinxcontrib-appleh | 28 KB     | #####6     |  57%
# sphinxcontrib-appleh | 28 KB     | ########## | 100%
#
# anaconda-custom      | 2 KB      |            |   0%
# anaconda-custom      | 2 KB      | ########## | 100%
#
# autopep8-1.5.2       | 39 KB     |            |   0%
# autopep8-1.5.2       | 39 KB     | ####1      |  41%
# autopep8-1.5.2       | 39 KB     | ########## | 100%
#
# python-language-serv | 75 KB     |            |   0%
# python-language-serv | 75 KB     | ##1        |  21%
# python-language-serv | 75 KB     | ########## | 100%
#
# pywin32-ctypes-0.2.0 | 38 KB     |            |   0%
# pywin32-ctypes-0.2.0 | 38 KB     | ####2      |  43%
# pywin32-ctypes-0.2.0 | 38 KB     | ########## | 100%
#
# fsspec-0.7.4         | 55 KB     |            |   0%
# fsspec-0.7.4         | 55 KB     | ##9        |  29%
# fsspec-0.7.4         | 55 KB     | ########## | 100%
#
# argh-0.26.2          | 33 KB     |            |   0%
# argh-0.26.2          | 33 KB     | ####8      |  48%
# argh-0.26.2          | 33 KB     | ########## | 100%
#
# diff-match-patch-201 | 37 KB     |            |   0%
# diff-match-patch-201 | 37 KB     | ####2      |  43%
# diff-match-patch-201 | 37 KB     | ########## | 100%
#
# certifi-2020.6.20    | 151 KB    |            |   0%
# certifi-2020.6.20    | 151 KB    | #          |  11%
# certifi-2020.6.20    | 151 KB    | #######4   |  74%
# certifi-2020.6.20    | 151 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# WARNING: The conda.compat module is deprecated and will be removed in a future release.
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.6.11
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# 'ET' is not recognized as an internal or external command,
# operable program or batch file.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Anuj\Anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
#
# folium-0.5.0         | 45 KB     |            |   0%
# folium-0.5.0         | 45 KB     | ###5       |  35%
# folium-0.5.0         | 45 KB     | ########## | 100%
#
# vincent-0.4.4        | 28 KB     |            |   0%
# vincent-0.4.4        | 28 KB     | #####7     |  58%
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
# altair-4.1.0         | 614 KB    |            |   0%
# altair-4.1.0         | 614 KB    | 2          |   3%
# altair-4.1.0         | 614 KB    | #5         |  16%
# altair-4.1.0         | 614 KB    | ##6        |  26%
# altair-4.1.0         | 614 KB    | ####1      |  42%
# altair-4.1.0         | 614 KB    | #####2     |  52%
# altair-4.1.0         | 614 KB    | ######7    |  68%
# altair-4.1.0         | 614 KB    | #########3 |  94%
# altair-4.1.0         | 614 KB    | ########## | 100%
#
# branca-0.4.1         | 26 KB     |            |   0%
# branca-0.4.1         | 26 KB     | ######1    |  62%
# branca-0.4.1         | 26 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# import Libraries that we need
import requests
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %% [markdown]
# # Scrap data from wikipedia page & Create dataframe

# %%
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# # Read table

# %%
table = soup.find('tbody')
rows = table.select('tr')
row = [r.get_text() for r in rows]

# %% [markdown]
# # Create a clean dataframe

# %%
df = pd.DataFrame(row)
df1 = df[0].str.split('\n', expand=True)
df2 = df1.rename(columns=df1.iloc[0])
df3 = df2.drop(df2.index[0])
df4 = df3[df3.Borough != 'Not assigned']
df5 = df4.groupby(['Postal Code', 'Borough'], sort = False).agg(','.join)
df5.reset_index(inplace = True)
df6 = df5.replace("Not assigned", "Queen's Park")
df6.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# # Read csv file of Geospatial_data

# %%
url = "http://cocl.us/Geospatial_data"
df7 = pd.read_csv(url)

df7.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# # Create a new dataframe to merge first & second dataframe

# %%
df8 = pd.merge(df6, df7, on='Postal Code')
df8.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# # Show how many Borough & Neighbourhood in the dataframe

# %%
print('The dataframe has {} Borough and {} Neighbourhood.'.format(
        len(df8['Borough'].unique()),
        df8.shape[0]
    )
)
# Out:
# The dataframe has 10 Borough and 103 Neighbourhood.

# %% [markdown]
# # Create a new dataframe for only boroughs that contain the word Toronto

# %%
Toronto=df8[df8['Borough'].str.contains('Toronto')]
Toronto
# Out:
#     Postal Code           Borough  \
# 2           M5A  Downtown Toronto
# 4           M7A  Downtown Toronto
# 9           M5B  Downtown Toronto
# 15          M5C  Downtown Toronto
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# 30          M5H  Downtown Toronto
# 31          M6H      West Toronto
# 36          M5J  Downtown Toronto
# 37          M6J      West Toronto
# 41          M4K      East Toronto
# 42          M5K  Downtown Toronto
# 43          M6K      West Toronto
# 47          M4L      East Toronto
# 48          M5L  Downtown Toronto
# 54          M4M      East Toronto
# 61          M4N   Central Toronto
# 62          M5N   Central Toronto
# 67          M4P   Central Toronto
# 68          M5P   Central Toronto
# 69          M6P      West Toronto
# 73          M4R   Central Toronto
# 74          M5R   Central Toronto
# 75          M6R      West Toronto
# 79          M4S   Central Toronto
# 80          M5S  Downtown Toronto
# 81          M6S      West Toronto
# 83          M4T   Central Toronto
# 84          M5T  Downtown Toronto
# 86          M4V   Central Toronto
# 87          M5V  Downtown Toronto
# 91          M4W  Downtown Toronto
# 92          M5W  Downtown Toronto
# 96          M4X  Downtown Toronto
# 97          M5X  Downtown Toronto
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
#
#                                           Neighborhood   Latitude  Longitude
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 9                             Garden District, Ryerson  43.657162 -79.378937
# 15                                      St. James Town  43.651494 -79.375418
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 30                            Richmond, Adelaide, King  43.650571 -79.384568
# 31                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 36   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 37                            Little Portugal, Trinity  43.647927 -79.419750
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# 42            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 43        Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 47                      India Bazaar, The Beaches West  43.668999 -79.315572
# 48                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 54                                     Studio District  43.659526 -79.340923
# 61                                       Lawrence Park  43.728020 -79.388790
# 62                                            Roselawn  43.711695 -79.416936
# 67                                    Davisville North  43.712751 -79.390197
# 68     Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 69                       High Park, The Junction South  43.661608 -79.464763
# 73                  North Toronto West,  Lawrence Park  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 79                                          Davisville  43.704324 -79.388790
# 80                      University of Toronto, Harbord  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 86   Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 87   CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 91                                            Rosedale  43.679563 -79.377529
# 92                                      Stn A PO Boxes  43.646435 -79.374846
# 96                         St. James Town, Cabbagetown  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558

# %% [markdown]
# # Generate map to visualize neighborhoods and how they cluster together

# %%
address = 'Toronto'
geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

Toronto_map = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(Toronto['Latitude'], Toronto['Longitude'], 
                                           Toronto['Borough'], Toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Toronto_map)  
    
Toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
